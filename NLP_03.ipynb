# %%
import nltk
import random

nltk.download('punkt')
nltk.download('gutenberg')

words = nltk.corpus.gutenberg.words()

bigrams = list(nltk.bigrams(words))

starting_word = "the"
generated_text = [starting_word]

for _ in range(20):
    possible_words = [word2 for (word1, word2) in bigrams if word1.lower() ==generated_text[-1].lower()]

    next_word = random.choice(possible_words)
    generated_text.append(next_word)
print(' '.join(generated_text))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Online\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\Online\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# the more rational and Moses . 23 For him the passover on both dropt , hid for heaven ; and honey
